# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from acquire import get_sales_items_stores

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 250)

# %%
sales_df = pd.read_csv('sales.csv')
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   item         913000 non-null  int64
#  1   sale_amount  913000 non-null  float64
#  2   sale_date    913000 non-null  object
#  3   sale_id      913000 non-null  int64
#  4   store        913000 non-null  int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 34.8+ MB

# %%
#df = get_sales_items_stores()

df.info()
df.head()
# Out:
# Getting page 3 of 3: https://api.data.codeup.com/api/v1/items?page=3Reading from CSV file...

# %%
#df = df.drop(columns= ['Unnamed: 0', 'Unnamed: 0_x', 'Unnamed: 0_y'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_id        913000 non-null  int64
#  1   sale_amount    913000 non-null  float64
#  2   sale_date      913000 non-null  object
#  3   sale_id        913000 non-null  int64
#  4   store_id       913000 non-null  int64
#  5   item_brand     913000 non-null  object
#  6   item_name      913000 non-null  object
#  7   item_price     913000 non-null  float64
#  8   item_upc12     913000 non-null  int64
#  9   item_upc14     913000 non-null  int64
#  10  store_address  913000 non-null  object
#  11  store_city     913000 non-null  object
#  12  store_state    913000 non-null  object
#  13  store_zipcode  913000 non-null  int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 97.5+ MB

# %%
empty_hour_id = '00:00:00 GMT'
df.sale_date = df.sale_date.str.rstrip(empty_hour_id)

# %%
df.head()
# Out:
#    item_id  sale_amount         sale_date  sale_id  store_id item_brand  \
# 0        1         13.0  Tue, 01 Jan 2013        1         1   Riceland
# 1        1         11.0  Wed, 02 Jan 2013        2         1   Riceland
# 2        1         14.0  Thu, 03 Jan 2013        3         1   Riceland
# 3        1         13.0  Fri, 04 Jan 2013        4         1   Riceland
# 4        1         10.0  Sat, 05 Jan 2013        5         1   Riceland
#
#                         item_name  item_price   item_upc12   item_upc14  \
# 0  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 1  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 2  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 3  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 4  Riceland American Jazmine Rice        0.84  35200264013  35200264013
#
#             store_address   store_city store_state  store_zipcode
# ...

# %%
df.sale_date = pd.to_datetime(df.sale_date)
df = df.set_index(df.sale_date)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 913000 entries, 2013-01-01 to 2017-12-31
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_id        913000 non-null  int64
#  1   sale_amount    913000 non-null  float64
#  2   sale_date      913000 non-null  datetime64[ns]
#  3   sale_id        913000 non-null  int64
#  4   store_id       913000 non-null  int64
#  5   item_brand     913000 non-null  object
#  6   item_name      913000 non-null  object
#  7   item_price     913000 non-null  float64
#  8   item_upc12     913000 non-null  int64
#  9   item_upc14     913000 non-null  int64
#  10  store_address  913000 non-null  object
#  11  store_city     913000 non-null  object
#  12  store_state    913000 non-null  object
#  13  store_zipcode  913000 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(5)
# memory usage: 104.5+ MB

# %%
df['month'] = df.index.strftime('%m-%b')
df['week_day'] = df.index.strftime('%w-%a')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 913000 entries, 2013-01-01 to 2017-12-31
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_id        913000 non-null  int64
#  1   sale_amount    913000 non-null  float64
#  2   sale_date      913000 non-null  datetime64[ns]
#  3   sale_id        913000 non-null  int64
#  4   store_id       913000 non-null  int64
#  5   item_brand     913000 non-null  object
#  6   item_name      913000 non-null  object
#  7   item_price     913000 non-null  float64
#  8   item_upc12     913000 non-null  int64
#  9   item_upc14     913000 non-null  int64
#  10  store_address  913000 non-null  object
#  11  store_city     913000 non-null  object
#  12  store_state    913000 non-null  object
#  13  store_zipcode  913000 non-null  int64
#  14  month          913000 non-null  object
#  15  week_day       913000 non-null  object
# ...

# %%
df.head()
# Out:
#             item_id  sale_amount  sale_date  sale_id  store_id item_brand  \
# sale_date
# 2013-01-01        1         13.0 2013-01-01        1         1   Riceland
# 2013-01-02        1         11.0 2013-01-02        2         1   Riceland
# 2013-01-03        1         14.0 2013-01-03        3         1   Riceland
# 2013-01-04        1         13.0 2013-01-04        4         1   Riceland
# 2013-01-05        1         10.0 2013-01-05        5         1   Riceland
#
#                                  item_name  item_price   item_upc12  \
# sale_date
# 2013-01-01  Riceland American Jazmine Rice        0.84  35200264013
# 2013-01-02  Riceland American Jazmine Rice        0.84  35200264013
# 2013-01-03  Riceland American Jazmine Rice        0.84  35200264013
# 2013-01-04  Riceland American Jazmine Rice        0.84  35200264013
# 2013-01-05  Riceland American Jazmine Rice        0.84  35200264013
#
#              item_upc14           store_address   store_city store_state  \
# sale_date
# ...

# %%
df['sales_total'] = df.sale_amount * df.item_price
df.head()
# Out:
#             item_id  sale_amount  sale_date  sale_id  store_id item_brand  \
# sale_date
# 2013-01-01        1         13.0 2013-01-01        1         1   Riceland
# 2013-01-02        1         11.0 2013-01-02        2         1   Riceland
# 2013-01-03        1         14.0 2013-01-03        3         1   Riceland
# 2013-01-04        1         13.0 2013-01-04        4         1   Riceland
# 2013-01-05        1         10.0 2013-01-05        5         1   Riceland
#
#                                  item_name  item_price   item_upc12  \
# sale_date
# 2013-01-01  Riceland American Jazmine Rice        0.84  35200264013
# 2013-01-02  Riceland American Jazmine Rice        0.84  35200264013
# 2013-01-03  Riceland American Jazmine Rice        0.84  35200264013
# 2013-01-04  Riceland American Jazmine Rice        0.84  35200264013
# 2013-01-05  Riceland American Jazmine Rice        0.84  35200264013
#
#              item_upc14           store_address   store_city store_state  \
# sale_date
# ...
